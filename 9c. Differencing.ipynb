# %%
#Importing libraries
import pandas as pd
# %matplotlib inline
from statsmodels.tsa.statespace.tools import diff

# %%
#Loading data
data = pd.read_csv('C:/Users/bhavi/OneDrive/Desktop/Data/Time_Series_Data/samples.csv', index_col=0, parse_dates=True)

# %%
#Checking data
data.head()
# Out:
#              a   b  c   d
# 1950-01-01  36  27  0  67
# 1950-02-01  58  22  3  31
# 1950-03-01  61  17  5  67
# 1950-04-01  37  15  8  47
# 1950-05-01  66  13  8  62

# %%
#Plotting a feature
data['a'].plot();
#Stationary data

# %%
#Plotting b feature
data['b'].plot();
#Non stationary data

# %%
#Taking difference from non stationary data manually
data['b'] - data['b'].shift(1)
# Out:
# 1950-01-01     NaN
# 1950-02-01    -5.0
# 1950-03-01    -5.0
# 1950-04-01    -2.0
# 1950-05-01    -2.0
#               ...
# 1959-08-01     3.0
# 1959-09-01     4.0
# 1959-10-01    -7.0
# 1959-11-01    17.0
# 1959-12-01   -14.0
# Name: b, Length: 120, dtype: float64

# %%
#Taking difference from non stationary data with diff function
diff(data['b'], k_diff=1)
# Out:
# 1950-02-01    -5.0
# 1950-03-01    -5.0
# 1950-04-01    -2.0
# 1950-05-01    -2.0
# 1950-06-01     3.0
#               ...
# 1959-08-01     3.0
# 1959-09-01     4.0
# 1959-10-01    -7.0
# 1959-11-01    17.0
# 1959-12-01   -14.0
# Name: b, Length: 119, dtype: float64

# %%
#Plotting difference
diff(data['b'], k_diff=1).plot();
